# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os
from pathlib import Path
import json
import re
import time
from tqdm import tqdm
from bs4 import BeautifulSoup, Tag
import pandas as pd
import requests
import webbrowser, requests,time
from itertools import batched

from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

sys.path.append("../src/")

from amc_scraper import amc_scraper

# %%
soup = amc_scraper.get_first_soup('AMC_12')
link_elements = soup.select(amc_scraper.LINK_SELECTOR['AMC_12'])
elem = link_elements[11]
amc_scraper.get_contest_metadata_from_link('AMC_12',elem)

# %%
metadata = amc_scraper.get_contest_metadata('AMC_12',save_json=True)

# %%
_,pairs = amc_scraper.generate_all_and_pairs('p','AMC_12')

# %%
p = pairs[0]
problems = amc_scraper.get_problems_from_source(p[1],p[2],p[3])

# %%
_,_ = amc_scraper.get_problems_full('AMC_12',save_json = True, num = 100)

# %%
_,_ = amc_scraper.get_answers_full('AMC_12',save_json = True)

# %%
p = pairs[9]
solutions = amc_scraper.get_solutions_from_source(p[1],p[3])

# %%
_,_ = amc_scraper.get_solutions_full('AMC_12',save_json = True, num = 50)

# %%
amc_scraper.get_figures_problem('AMC_12')

# %%
amc_scraper.get_figures_solution('AMC_12')

# %%
amc_scraper.generate_tex_folder('AMC_12','nosol')

# %%
amc_scraper.generate_tex_folder('AMC_12','withsolution')

# %%
amc_scraper.generate_html_json('USAMO')

# %%
datapath = amc_scraper.DATA_PATH
contestpath = [item for item in datapath.iterdir()]
full_problem = []

for contest in contestpath :
    file = contest / 'full_tex.json'
    with open(file,'r',encoding='utf-8') as f :
        data = json.load(f)
        full_problem+=data
df_full = pd.DataFrame(full_problem)

# %%
df_full = pd.DataFrame(full_problem)
df_full = df_full.loc[:,['id','contest','version','year','problem_number','problem_statement_tex','answer','difficulty','solutions_statement_tex']]
df_full.to_excel('../AMC_full.xlsx',index = False)

# %%
len(df_full)
# Out:
# 6957
