# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os
from pathlib import Path
import json
import re
import time
from tqdm import tqdm
from bs4 import BeautifulSoup, Tag
import pandas as pd
import requests
import webbrowser, requests,time
from itertools import batched

from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

sys.path.append("../src/")

from amc_scraper import amc_scraper

# %%
metadata = amc_scraper.get_contest_metadata('USAMO',save_json=True)

# %%
_,pairs = amc_scraper.generate_all_and_pairs('p','USAMO')

# %%
p = pairs[-1]
problems = amc_scraper.get_problems_from_source(p[1],p[2],p[3])

# %%
_,_ = amc_scraper.get_problems_full('USAMO',save_json = True, num = 100)

# %%
_,_ = amc_scraper.get_answers_full('USAMO',save_json = True)

# %%
p = pairs[9]
solutions = amc_scraper.get_solutions_from_source(p[1],p[3])

# %%
_,_ = amc_scraper.get_solutions_full('USAMO',save_json = True, num = 50)

# %%
amc_scraper.get_figures_problem('USAMO')

# %%
amc_scraper.get_figures_solution('USAMO')

# %%
amc_scraper.generate_tex_folder('USAMO','nosol')

# %%
amc_scraper.generate_tex_folder('USAMO','withsolution')

# %%
# amc_scraper.generate_html_json('AIME')
