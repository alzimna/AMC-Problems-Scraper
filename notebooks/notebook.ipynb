# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os
from pathlib import Path
import json
import re
import time
from tqdm import tqdm
from bs4 import BeautifulSoup, Tag
import pandas as pd
import requests
import webbrowser, requests,time
from itertools import batched

from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

sys.path.append("../src/")

from amc_scraper import amc_scraper

# %%
metadata = amc_scraper.get_contest_metadata('AIME',save_json=True)

# %%
_,_ = amc_scraper.get_problems_full('AIME',save_json = True, num = 100)

# %%
_,_ = amc_scraper.get_answers_full('AIME',save_json = True)

# %%
_,_ = amc_scraper.get_solutions_full('AIME',save_json = True, num = 40)

# %%
amc_scraper.get_figures_problem('AIME')

# %%
amc_scraper.get_figures_solution('AIME')

# %%
amc_scraper.generate_tex_folder('AIME','nosol')

# %%
amc_scraper.generate_tex_folder('AIME','withsolution')

# %%
# amc_scraper.generate_html_json('AIME')
