# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os
from pathlib import Path
import json
import re
import time
from tqdm import tqdm
from bs4 import BeautifulSoup, Tag
import pandas as pd
import requests
import webbrowser, requests,time
from itertools import batched

from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

sys.path.append("../src/")

from amc_scraper import amc_scraper

# %%
metadata = amc_scraper.get_contest_metadata('AHSME',save_json=True)

# %%
_,_ = amc_scraper.get_problems_full('AHSME',save_json = True, num = 100)
# Out:
# Progress:  40%|████      | 4/10 [01:57<02:36, 26.04s/chunk, downloaded=600, last_version=I, last_year=1980]
# ====================== Retrieving 1978 AHSME Problems Failed Retrying...(1) ======================
# ====================== Retrieving 1978 AHSME Problems Failed Retrying...(2) ======================
# Progress:  50%|█████     | 5/10 [02:37<02:35, 31.08s/chunk, downloaded=750, last_version=I, last_year=1975]
# ====================== Retrieving 1974 AHSME Problems Failed Retrying...(1) ======================
# ====================== Retrieving 1971 AHSME Problems Failed Retrying...(1) ======================
# ====================== Retrieving 1974 AHSME Problems Failed Retrying...(2) ======================
# Progress:  70%|███████   | 7/10 [03:36<01:26, 28.88s/chunk, downloaded=1110, last_version=I, last_year=1965]
# ====================== Retrieving 1962 AHSME Problems Failed Retrying...(1) ======================
# ...

# %%
_,_ = amc_scraper.get_answers_full('AHSME',save_json = True)
# Out:
# Progress:  10%|█         | 1/10 [00:18<02:43, 18.13s/chunk, downloaded=150, last_version=I, last_year=1995]
# ===================== Retrieving 1993 AHSME Answer Key Failed Retrying...(1) =====================
# ===================== Retrieving 1994 AHSME Answer Key Failed Retrying...(1) =====================
# ===================== Retrieving 1991 AHSME Answer Key Failed Retrying...(1) =====================
# ===================== Retrieving 1994 AHSME Answer Key Failed Retrying...(2) =====================
# Progress:  20%|██        | 2/10 [00:59<04:12, 31.58s/chunk, downloaded=300, last_version=I, last_year=1990]
# ===================== Retrieving 1985 AHSME Answer Key Failed Retrying...(1) =====================
# ===================== Retrieving 1985 AHSME Answer Key Failed Retrying...(2) =====================
# Progress:  50%|█████     | 5/10 [02:21<02:12, 26.47s/chunk, downloaded=750, last_version=I, last_year=1975]
# ...

# %%
_,_ = amc_scraper.get_solutions_full('AHSME',save_json = True, num = 25)
# Out:
# Progress:  11%|█         | 1/9 [03:32<28:21, 212.71s/chunk, downloaded=100, last_version=I, last_year=1972]
# == Retrieving Solution 1969 AHSME Problem 32 Failed: content selector not found, retrying...(1) ==
# Progress:  22%|██▏       | 2/9 [07:20<25:51, 221.59s/chunk, downloaded=205, last_version=I, last_year=1969]
# == Retrieving Solution 1967 AHSME Problem 15 Failed: content selector not found, retrying...(1) ==
# Progress:  44%|████▍     | 4/9 [16:04<20:50, 250.17s/chunk, downloaded=440, last_version=I, last_year=1963]
# == Retrieving Solution 1962 AHSME Problem 6 Failed: content selector not found, retrying...(1) ===
# == Retrieving Solution 1962 AHSME Problem 5 Failed: content selector not found, retrying...(1) ===
# == Retrieving Solution 1962 AHSME Problem 24 Failed: content selector not found, retrying...(1) ==
# == Retrieving Solution 1962 AHSME Problem 27 Failed: content selector not found, retrying...(1) ==
# ...

# %%
amc_scraper.get_figures_problem('AHSME')
# Out:
# Progress: 100%|██████████| 195/195 [02:36<00:00,  1.25Figure/s]

# %%
amc_scraper.get_figures_solution('AHSME')
# Out:
# Progress: 100%|██████████| 235/235 [05:31<00:00,  1.41s/Figure]

# %%
amc_scraper.generate_tex_folder('AHSME','nosol')

# %%
amc_scraper.generate_tex_folder('AHSME','withsolution')

# %%
# amc_scraper.generate_html_json('AIME')
